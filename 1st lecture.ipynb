# %%
10+4
# Out:
# 14

# %%
20-7
# Out:
# 13

# %%
#comment

# %%
#to get current working directory
import os
os.getcwd()
# Out:
# 'C:\\Users\\onkar\\Datascience DSP37'

# %%
pwd
# Out:
# 'C:\\Users\\onkar\\Datascience DSP37'

# %%
a=10
a
# Out:
# 10

# %%
A   #python is case sensitive
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-8-a6fd1c6704a8> in <module>
# ----> 1 A   #python is case sensitive
#
# NameError: name 'A' is not defined

# %%
b=12
c=14
d=34

b
c
d    #print only value of d
# Out:
# 34

# %%
print(b)
print(c)
print(d)
# Out:
# 12
# 14
# 34

# %%
name ="Mr. A"
age = 20
print("name is ", name, "and age is ", age)
# Out:
# name is  Mr. A and age is  20

# %%
#delete the variable
del(name)

# %%
name
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-18-9bc0cb2ed6de> in <module>
# ----> 1 name
#
# NameError: name 'name' is not defined

# %%
age==21      #== for checks the value
# Out:
# False

# %%
age<21
# Out:
# True

# %%
# Datatypes in python
#1. Tuple 
#2. list
#3. dictionary
#4. set

# %%
#tuple is one dimensional representation of data which can be of mixed type and it is immutable

# %%
first_tuple= (10,20,30,2,3,4,5,'pune')

# %%
type(first_tuple)     #showing class of variable
# Out:
# tuple

# %%
first_tuple[0]   #indexing start from zero
# Out:
# 10

# %%
first_tuple[-1]
# Out:
# 'pune'

# %%
len(first_tuple)   #to get rhe count
# Out:
# 8

# %%
first_tuple[2]
# Out:
# 30

# %%
first_tuple[2] = 555   #trying to replace 33 with 555
#tuples are immutable means you cant add, delete or change the value of variable
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-30-9afef6605173> in <module>
# ----> 1 first_tuple[2] = 555   #trying to replace 33 with 555
#       2 #tuples are immutable means you cant add, delete or change the value of variable
#
# TypeError: 'tuple' object does not support item assignment

# %%
t2= (5,5,7,10,20,20,20,30,45,30)

# %%
t2.count(20)
# Out:
# 3

# %%
t2.index(20)
# Out:
# 4

# %%
len(t2)
# Out:
# 10

# %%
# list is one dimensional representation of data which can be of mixed type and it is mutable

# %%
#   () for tuple
#   [] for list
#   {} for dictionary

# %%
first_list = [10,20,30,2,3,4,5,'pune', 'mumbai', 'pune']
first_list
# Out:
# [10, 20, 30, 2, 3, 4, 5, 'pune', 'mumbai', 'pune']

# %%
type(first_list)
# Out:
# list

# %%
len(first_list)
# Out:
# 10

# %%
first_list[7]
# Out:
# 'pune'

# %%
first_list[7] = "Nashik"   #list is mutable

# %%
first_list
# Out:
# [10, 20, 30, 2, 3, 4, 5, 'Nashik', 'mumbai', 'pune']

# %%
first_list.append("Kolhapur")   #add element at the end using append functions

# %%
first_list
# Out:
# [10, 20, 30, 2, 3, 4, 5, 'Nashik', 'mumbai', 'pune', 'Kolhapur']

# %%
first_list.append(# press shift tab)
# Out:
#   File "<ipython-input-45-813de1e70c2e>", line 1
#     first_list.append(# press shift tab)
#                                         ^
# SyntaxError: unexpected EOF while parsing

# %%
first_list
# Out:
# [10, 20, 30, 2, 3, 4, 5, 'Nashik', 'mumbai', 'pune', 'Kolhapur']

# %%
first_list.clear() #clear the list

# %%
first_list
# Out:
# []

# %%
l1=[10,23,4,5,56,6,7,"data", "science"]

# %%
type(l1)
# Out:
# list

# %%
l1.count(23)
# Out:
# 1

# %%
l1.extend("abcd")

# %%
l1
# Out:
# [10, 23, 4, 5, 56, 6, 7, 'data', 'science', 'a', 'b', 'c', 'd']

# %%
l1=[10,23,4,5,56,6,7,"data", "science"]
l2=["class"]

# %%
l1.extend(l2) # append two list at the endn

# %%
l1
# Out:
# [10, 23, 4, 5, 56, 6, 7, 'data', 'science', 'class']

# %%
l3=[10,23,4,5,56,6,7,"data", "science"]
l4=["class", "python"]

# %%
l3.extend(l4)

# %%
l3
# Out:
# [10, 23, 4, 5, 56, 6, 7, 'data', 'science', 'class', 'python']

# %%
l3.index(10)
# Out:
# 0

# %%
l3.index(100)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-60-1c8b8fe979f3> in <module>
# ----> 1 l3.index(100)
#
# ValueError: 100 is not in list

# %%
print(l3)
l3.pop() #remove the element at the index and default is last element
print(l3)
# Out:
# [10, 23, 4, 5, 56, 6, 7, 'data', 'science', 'class', 'python']
# [10, 23, 4, 5, 56, 6, 7, 'data', 'science', 'class']

# %%
print(l3)
l3.pop(4) #remove the element at the index and default is last element
print(l3)
# Out:
# [10, 23, 4, 5, 56, 6, 7, 'data', 'science', 'class']
# [10, 23, 4, 5, 6, 7, 'data', 'science', 'class']

# %%
l5= [5,6,7,9,100,120,20,20,31,31,45]

# %%
l5.pop()
# Out:
# 45

# %%
l5.pop(4)  #reove the index position at 4
# Out:
# 100

# %%
l5= [5,6,7,9,100,120,20,20,31,31,45]

# %%
l5.remove(9)   #remove 9 in list
l5
# Out:
# [5, 6, 7, 100, 120, 20, 20, 31, 31, 45]

# %%
l5.remove(125)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-70-963108787dc8> in <module>
# ----> 1 l5.remove(125)
#
# ValueError: list.remove(x): x not in list

# %%
l5.remove(20) #remove the first occurance
l5
# Out:
# [5, 6, 7, 100, 120, 20, 31, 31, 45]

# %%
l5.reverse()
l5
# Out:
# [45, 31, 31, 20, 120, 100, 7, 6, 5]

# %%
l5.sort() #sort in ascending order
l5
# Out:
# [5, 6, 7, 20, 31, 31, 45, 100, 120]

# %%
l5.sort(reverse=True) #sort in ascending order
l5
# Out:
# [120, 100, 45, 31, 31, 20, 7, 6, 5]

# %%
l6 = [5,6,7,8,9,100,120,20,20,31,31,45]
l6.sort()
l6.reverse()

# %%
l6
# Out:
# [120, 100, 45, 31, 31, 20, 20, 9, 8, 7, 6, 5]

# %%
l8 = list( [10,20,400,50,43,'data'] )

# %%
l8
# Out:
# [10, 20, 400, 50, 43, 'data']

# %%
type(l8)
# Out:
# list

# %%
aa= (10, 30)
type(aa)
# Out:
# tuple

# %%
bb = list(aa)
bb
# Out:
# [10, 30]

# %%
type(bb)
# Out:
# list

# %%
# dictionary is used to store data in key value format and it is also used to create a dataframe

# %%
dict1 = {'name': 'mr. A', 
         'salary': 100 , 
         'Age':20}
dict1
# Out:
# {'name': 'mr. A', 'salary': 100, 'Age': 20}

# %%
dict1.keys()
# Out:
# dict_keys(['name', 'salary', 'Age'])

# %%
dict1.values()
# Out:
# dict_values(['mr. A', 100, 20])

# %%
dict1.

# %%
emp_details = {'name': ('A','B', 'C', 'D', 'E', 'F'), 
               'Age': (20,30,31,35,27,29) , 
               'salary':(100,200,120,300,450,600)}

# %%
emp_details
# Out:
# {'name': ('A', 'B', 'C', 'D', 'E', 'F'),
#  'Age': (20, 30, 31, 35, 27, 29),
#  'salary': (100, 200, 120, 300, 450, 600)}

# %%
emp_details.keys()
# Out:
# dict_keys(['name', 'Age', 'salary'])

# %%
emp_details.values()
# Out:
# dict_values([('A', 'B', 'C', 'D', 'E', 'F'), (20, 30, 31, 35, 27, 29), (100, 200, 120, 300, 450, 600)])

# %%
import pandas as pd

# %%
df = pd.DataFrame(emp_details)

# %%
df
# Out:
#   name  Age  salary
# 0    A   20     100
# 1    B   30     200
# 2    C   31     120
# 3    D   35     300
# 4    E   27     450
# 5    F   29     600

# %%
import numpy as np

# %%
df2 = pd.DataFrame()
df2
# Out:
# Empty DataFrame
# Columns: []
# Index: []

# %%
#set
# set is one dimentional representation of unique data where indexing is not possible

# %%
s1 = set([10,20,30,30, 'pune']) # remove the duplication of data
s1
# Out:
# {10, 20, 30, 'pune'}

# %%
s1[0]#indexing not available
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-106-bfed54b371ac> in <module>
# ----> 1 s1[0]
#
# TypeError: 'set' object is not subscriptable

# %%
list2= list(s1)
list2
# Out:
# [10, 20, 'pune', 30]

# %%
s1 = set([10,20,30,30, 'pune'])
list3 = list(s1)
list3
# Out:
# [10, 20, 'pune', 30]

# %%
#format printing

# %%
state = 'Maharashtra'
country = 'India'
print("he lives in state {} and country {}" .format(state, country))
# Out:
# he lives in state Maharashtra and country India

# %%
#colon is something like a new line

# %%
state = 'Maharashtra' ; country = 'India' ; print("he lives in state {} and country {}" .format(state, country))
# Out:
# he lives in state Maharashtra and country India

# %%
print("he lives in state of", state, end = " ")
print("present in ", country)
# Out:
# he lives in state of Maharashtra present in  India

# %%
# input function is used to take inoput from the user

# %%
num = input("no you wish to enter ")
# Out:
# no you wish to enter 234

# %%
num
# Out:
# '234'

# %%
type(num)
# Out:
# str

# %%
no= int(input())
# Out:
# 10

# %%
no+3
# Out:
# 13

# %%
#problem with input function is that it stores all data in string

# %%
num1 = eval(input("enter no "))
# Out:
# enter no 122

# %%
num1
# Out:
# 122
